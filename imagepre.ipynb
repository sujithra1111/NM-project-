# %%
import cv2
import numpy as np

# Load the image
image = cv2.imread('/content/sample_data/angry-birds-birds-.jpg')

# 1. Resize the image (to a specific width and height)
resized_image = cv2.resize(image, (640, 480))  # Resize to 640x480 pixels

# 2. Convert the image to grayscale
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY)

# 3. Apply Gaussian Blur (to reduce noise)
blurred_image = cv2.GaussianBlur(gray_image, (5, 5), 0)

# 4. Thresholding (Binary thresholding)
_, thresholded_image = cv2.threshold(gray_image, 127, 255, cv2.THRESH_BINARY)

# 5. Edge Detection using Canny
edges = cv2.Canny(gray_image, 100, 200)

# 6. Dilation and Erosion
kernel = np.ones((5, 5), np.uint8)
dilated_image = cv2.dilate(thresholded_image, kernel, iterations=1)
eroded_image = cv2.erode(thresholded_image, kernel, iterations=1)

# 7. Histogram Equalization (Improves contrast)
equalized_image = cv2.equalizeHist(gray_image)

# Display the processed images
cv2.imshow("Original Image", image)
cv2.imshow("Resized Image", resized_image)
cv2.imshow("Grayscale Image", gray_image)
cv2.imshow("Blurred Image", blurred_image)
cv2.imshow("Thresholded Image", thresholded_image)
cv2.imshow("Edges", edges)
cv2.imshow("Dilated Image", dilated_image)
cv2.imshow("Eroded Image", eroded_image)
cv2.imshow("Equalized Image", equalized_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# ---------------------------------------------------------------------------
# DisabledFunctionError                     Traceback (most recent call last)
# <ipython-input-4-4a81fe784f6e> in <cell line: 0>()
#      29
#      30 # Display the processed images
# ---> 31 cv2.imshow("Original Image", image)
#      32 cv2.imshow("Resized Image", resized_image)
#      33 cv2.imshow("Grayscale Image", gray_image)
#
# /usr/local/lib/python3.11/dist-packages/google/colab/_import_hooks/_cv2.py in wrapped(*args, **kwargs)
#      48   def wrapped(*args, **kwargs):
#      49     if not os.environ.get(env_var, False):
# ---> 50       raise DisabledFunctionError(message, name or func.__name__)
#      51     return func(*args, **kwargs)
#      52
#
# DisabledFunctionError: cv2.imshow() is disabled in Colab, because it causes Jupyter sessions
# to crash; see https://github.com/jupyter/notebook/issues/3935.
# As a substitution, consider using
#   from google.colab.patches import cv2_imshow

# %%
import cv2
import numpy as np
from google.colab.patches import cv2_imshow # Import cv2_imshow

# Load the image
image = cv2.imread('/content/sample_data/angry-birds-birds-.jpg')

# ... (rest of your image processing code remains the same) ...

# Display the processed images using cv2_imshow
cv2_imshow(image) # Use cv2_imshow instead of cv2.imshow
cv2_imshow(resized_image)
cv2_imshow(gray_image)
cv2_imshow(blurred_image)
cv2_imshow(thresholded_image)
cv2_imshow(edges)
cv2_imshow(dilated_image)
cv2_imshow(eroded_image)
cv2_imshow(equalized_image)

cv2.waitKey(0)
cv2.destroyAllWindows()
# Out:
# <PIL.Image.Image image mode=RGB size=728x410>
# <PIL.Image.Image image mode=RGB size=640x480>
# <PIL.Image.Image image mode=L size=728x410>
# <PIL.Image.Image image mode=L size=728x410>
# <PIL.Image.Image image mode=L size=728x410>
# <PIL.Image.Image image mode=L size=728x410>
# <PIL.Image.Image image mode=L size=728x410>
# <PIL.Image.Image image mode=L size=728x410>
# <PIL.Image.Image image mode=L size=728x410>
